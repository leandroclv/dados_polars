# %%
# %pip install polars
# %conda install
# Out:
# Requirement already satisfied: polars in /home/leandro/anaconda3/lib/python3.13/site-packages (1.36.1)
# Requirement already satisfied: polars-runtime-32==1.36.1 in /home/leandro/anaconda3/lib/python3.13/site-packages (from polars) (1.36.1)
# Note: you may need to restart the kernel to use updated packages.
# 2 channel Terms of Service accepted
#
# CondaValueError: too few arguments, must supply one of command line packages, --file or --revision
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import polars as pl
# Out:
# O Kernel deu pane ao executar o código na célula atual ou em uma célula anterior.
#
# Analise o código nas células para identificar uma possível causa da pane.
#
# Clique <a href='https://aka.ms/vscodeJupyterKernelCrash'>aqui</a> para obter mais informações.
#
# Consulte Jupyter <a href='command:jupyter.viewOutput'>log</a> para obter mais detalhes.

# %%
df = pl.DataFrame({
    'nome': ['Alice', 'Bob', 'Charlie', 'David'],
    'idade': [25,30,35,40],
    'cidade': ['São Paulo', 'Rio de Janeiro', 'Belo Horizonte', 'Porto Alegre']
})

# %%
df

# %%
#Exemplo de leitura csv público
url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv'
df = pl.read_csv(url)
df.head()

# %%
print(df.columns)

# %%
print(df.dtypes)

# %%
df.shape

# %%
df.describe
